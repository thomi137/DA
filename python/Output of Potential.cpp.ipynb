# %% [markdown]
# # Test Of Output Potential.cpp
#
# As a starting point to move my Master's Thesis into the new world, I started to make sense of my code again and recompiled some simple scripts. These should be easy to handle today using python as an evaluation tool. Wish I'd had that back then...

# %%
import io
import pandas as pd
from io import StringIO

# %matplotlib inline
import matplotlib.pyplot as plt

# %%
import sys
import subprocess

# %%
cmd = ["../src/checks/build/Potential"]
a = subprocess.Popen(cmd, stdout=subprocess.PIPE)
b = StringIO(a.communicate()[0].decode('utf-8'))
df = pd.read_csv(b, names=('xpos', 'pot'))

# %%
df.head()
# Out:
#       xpos      pot
# 0  5.00000  12.5000
# 1  4.99023  13.6343
# 2  4.98047  17.0641
# 3  4.97070  22.5808
# 4  4.96094  29.8508

# %%
df.dtypes
# Out:
# xpos    float64
# pot     float64
# dtype: object

# %%
df.plot(x="xpos", y="pot", figsize=(15, 5))
